# %% [markdown]
# ![image.png](attachment:image.png)
#
# This is more of a simplistic representation of crewAl specifically,
# but this is very similar to what you find on other frameworks out there.
# You have crews, you have agents,
# you have do's, you have processes, you have tasks.
# And the end goal is to produce a good outcome out of that.
# So you probably learn all the moving pieces.
# And should you ready to start building more complex crews to gather.
