# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![videoframe_223561.png](attachment:videoframe_223561.png)
#
# Role playing is the ability to kind of like just take the shape or form or function for something else will have a direct impact on what kind of answers you are going to get and kind of like what you are going for.
#
# Not saying better or worse, but the role, the context that you set for your agent does have a impact on how its going to respond

# %% [markdown]
# ![videoframe_287305.png](attachment:videoframe_287305.png)
#
# Focus is not only about context windows. Now a days LLMs have bigger and bigger context, even upto 1M tokens. But you mix things up too much much ,doesnot matter if you are talking about too many tools or if you are talking about too much of information or too much of context your model can lose important information and also open up oppertunities for hallucination. So which makes agents great is their ability to focus.
#
# It means it shuld focused upon amount of tools to focus upn, amount of content to focus on what they are trying to achieve. You should not rely on one agent at all, instaed ,many agents that work better together.

# %% [markdown]
# ![videoframe_352886.png](attachment:videoframe_352886.png)
#
# People tend to try to give a lot of tools for their agent.And that can get confusing as it overload agents with too many tools so they are going to have hard time to choose a tool. You should make sure you are providing them with the key tools to do the job that they need for.

# %% [markdown]
# ![videoframe_411731.png](attachment:videoframe_411731.png)
#
# Agents can take feedback from each other, they can delegate task to each other and by doing that they produce better outcomes. So agents should be able to collaborate with each other

# %% [markdown]
# ![videoframe_482006.png](attachment:videoframe_482006.png)
# AI applications in applying fuzzy inputs, fuzzy transformations and fuzzy outputs. It means you dont get necessarily stongly typed results but that doesn't mean you want hallucination though, or you wnats your agents to get stuck on random loops, or using same toold repeatedly or taking too long to give an answer.
#
# Implementation of guardrails agents from derailing and nudge agents to saty on track. And make sure to prevent from hallucinations and also makr sure that you get a reliable and consistent results throughout multi agent systems.

# %% [markdown]
# ![videoframe_557419.png](attachment:videoframe_557419.png)
#
# Memory is the ability of agent to remember what it has done. And use this data to inform new decisions and new executions. The ability to recollect what they did in past, learn from it and apply their knowledge into future execution.

# %% [markdown]
# ![videoframe_593704.png](attachment:videoframe_593704.png)
#
# Short term memory leaves only during the crew execution. every time you run crew it starts from the blank. These memories are useful as different agents try to accomplish different tasks, they store different things that they learned in memory. And this memory are shared across all agents.

# %% [markdown]
# ![videoframe_628779.png](attachment:videoframe_628779.png)
#
# Memmory is tored in a database locally. And that allow agents to learn from previous executions.So every time agent completes a task, it self critiques itself to learn what it should have done better

# %% [markdown]
# ![videoframe_674319.png](attachment:videoframe_674319.png)
#
# Short lived so its only needed during the execution. It stores- what are the subjects that are being discussed. So to gather entity short and long term memory plays a role on helping agents to get more reliable outcomes. If your agents didn't have memory you would probably get is likely different results every time that you run them.
