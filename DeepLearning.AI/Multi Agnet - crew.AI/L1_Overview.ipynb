# %% [markdown]
# Different ways agents collaborate with each other
# - Sequentially
# - Hierarchically
# - Asynchrously
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Agentic Automation**
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## AI Agents

# %% [markdown]
# ![image.png](attachment:image.png)  ![image-2.png](attachment:image-2.png)

# %% [markdown]
# LLMs do is the predict of most likely tokens and doing chat with them is having a similar experience as chatGPT where you need to give feedback to make sure that through the interaction between you & LLM , you get the results you need. You got to be there kind of  answering questions and interacting with it in order to get good results which you expected to get directly from the systems withouit involvement of you.
#
#  ![image.png](attachment:image.png) ![image-3.png](attachment:image-3.png)

# %% [markdown]
# AI Agents can actually can break up allowing LLM to operate autonomously . So the **agent is born** when LLM basically to get into in their thinking process throughout , it ask questions & answer the question itself to the pooint that it can move on and get better by itself. And throughout this thinking process , agent can come up with the better answer. Because its not the first answer that it would have given you, but it can then think through and optimize the answer upto the point that satisfies itslef and then spit it out.
#
# Tools allow your agent to interact with the external world. It could be calling API, it could be posting something, it could be gathering a data point.

# %% [markdown]
# ## Multi Agent System

# %% [markdown]
# ![image.png](attachment:image.png)  ![image-3.png](attachment:image-3.png)

# %% [markdown]
# Where instead of having just one agent , you can have multiple of them. So whenevr you task an agent with something this agent can also task anathor agent with anathor task.And in the end you get the final single answer.
#
# A researcher agent to focus on doing one thing and making sure that it finds all the sources that check all the sources include all the services and writer just use that in order to create the most amazing material ever.
#
# Other good thing is that you can run different LLM on different agents.
#
# ![image.png](attachment:image.png)  ![image-2.png](attachment:image-2.png)
